# %%
! pip install wordcloud

# %%
from collections import Counter
from wordcloud import WordCloud
import numpy as np
from PIL import *
import matplotlib.pyplot as plt

# %%
# 서원

li1 = '사외이사 본인 사망 중도 중도 이병 사외이사 이병 원인 이병 원인 중도 퇴임 사외이사 퇴임'
li2 = '서원주 서원주 운영 운영 서원 현대 정기 현대 부사 신부 부사 정기 인턴 아산'
li3 = '지원 도약 패키지 산학 협력 지원 서원대학교 도약 창업 창업 도약 스타트업 데스밸리 스타트업 패키지'
li4 = '상승세 상승 기중기 배열 상승세 상승  상승 서원 학원'
li5 = '외국인  상승 상승 상승 외국인 대량 외국인 대량 외국인 매도 매도 매도 주가'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white', 
    colormap='Blues',
    mask=mask_array,
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)

# %%
# 이월드

li1 = '페스티벌 개최 야외 웨딩 야외 웨딩 웨딩 페스티벌 페스티벌 야외 개최 이월드 체결'
li2 = '에스티 에스티 일장 할인 최대 할인 일장 최대 한가위 한가위 일장 최대'
li3 = '별빛 판타지 축제 크리스마스 크리스마스 판타지 별빛 축제 놀이 소외 계층 지역'
li4 = '주얼리 이월드 주얼리 디오스 스튜 스튜 디오스 주얼리 사업 사업 부비 스튜 사업 부비'
li5 = '온라인 최초 최초 온라인 업계 최초 업계 도전 감각 시민 저격'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white',
    colormap='Blues',
    mask=mask_array,
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)

# %%
# 주연테크

li1 = '기관 연속 기관 연속  상승 기관 장마 거래소 장마 종목 거래소'
li2 = '출시 하이마 하이 메이드 하이 롯데 롯데 하이마트 메이드 메이드 출시 하이마트'
li3 = '예약판매 노트북 예약판매 실시 노트북 슈퍼플라이 슈퍼플라 경량 경량 노트북 경량 실시 슈퍼플라이 예약판매'
li4 = '예약판매 노트북 예약판매 실시 노트북 슈퍼플라이 슈퍼플라 경량 경량 노트북 경량 실시 슈퍼플라이 예약판매'
li5 = '연속 기관 연속 기관 액면예약판매 노트북 예약판매 실시 노트북 슈퍼플라이 슈퍼플라 경량 경량 노트북 경량 실시 슈퍼플라이 예약판매크 액면병합 변경 메모 변경 메모 변경 상장'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white',
    colormap='Blues',
    mask=mask_array,
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)

# %%
# 써니전자

li1 = '안철수 관련 안철수 전자 써니 전자 상승 외국인 강세 오세훈'
li2 = '상승 안철수 현재 전자 현재 강세 전자 상승 외국인'
li3 = '상승 안철수 현재 전자 현재 강세 전자 상승 외국인'
li4 = '안랩 안철수 전자 안랩 안랩 안철수 강세 안철수 테마주 테마주'
li5 = '안철수 테마주 안철수 테마주 전자 안철수 테마주 강세 강세 주가'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white',
    colormap='Blues',
    mask=mask_array,
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)

# %%
# 삼성제약

li1 = '제약 제약 췌장암 제약 췌장암 췌장암 치료 치료 상한 이틀 상승'
li2 = '발표 발표 이틀 연속 이틀 결과 발표 결과 리아 리아 결과 강세'
li3 = '바이오 글로벌 글로벌 약사 약사 계약 바이오 글로벌 삼성 바이오 약사 증가 계약 증가'
li4 = '삼성 췌장암 신약 제약 연속'
li5 = '삼성 치료 제약 췌장암 췌장암 급등 췌장암 치료 이틀 급등 시장'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white',
    colormap='Blues',
    mask=mask_array,
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)

# %%
# 남성

li1 = '전자제품 제조 수출업 부동산 임대업'
li2 = 'Mobile Audio 비디오 라디오 GPS 스마트'
li3 = '임대업 라디오 라디오 제조 제품'
li4 = '카멜리아 카멜리아 시흥 중국 디지털 전자 전자'
li5 = '임대업 임대업 전자 스마트 엔에스에너지 유통 수출 수출'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white', 
    colormap='Blues',
    mask=mask_array,
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)

# %%
# 한창

li1 = '신재생 에너지 신재생 메타버스 부동산 부동산 마린 '
li2 = '마린 섬유 신재생 소화기 소화기 소화기'
li3 = '제조 제조 개발 개발 케미칼 케미칼'
li4 = '어반스테이 마린 섬유 소화기 소화기 아파트'
li5 = '부동산 자연친화 미래 에코 에코 부동산 아파트'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white',
    colormap='Blues',
    mask=mask_array, # 
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)

# %%
# 남선알미늄

li1 = '매도 플러스 남선 플러스 전량 에스 에스 플러스 전량 매도'
li2 = '구축 시스 공장 시스 남선 스마트 스마트 스마트 공장'
li3 = '주가 이낙연 이낙연 테마주 외국인 외국인 테마주 삼부 토건'
li4 = '영림 소프트 영림 소프트 공급 소프트 남선 알미늄 공급 변동'
li5 = '테마주 이낙연 주가 지지율 지지율 주춤 테마주 이낙연 이낙연 지지율'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white', 
    colormap='Blues',
    mask=mask_array,
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)

# %%
# 신성통상

li1 = '통상 론칭 통상 온라인 온라인 전용 온라인 더블유 론칭 더블유 전용'
li2 = '오지 신성 통상 신성 통상 스트릿 모나미 모나미 신성 애국 론칭'
li3 = '조달 자금 조달 자금 오지 통상 오지 스트릿 기업 자금'
li4 = '애국 급등 단기 천안 에스 단독'
li5 = '사임 아베 사임 아베 통상 일본 사임 소식 소식 강세 일본 아베'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white',
    colormap='Blues',
    mask=mask_array,
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)

# %%
# SK하이닉스

li1 = '대출 실탄 대출 하이닉스 실탄 조달 협력 은행권 자금  은행권 은행권 협력'
li2 = '오늘 대출 협약 달러 기업 협약 대출 오늘 사람 제철 삼성 테슬라'
li3 = '반도체 펀드 조성 조성 펀드 부장 반도체 수은 부장 펀드 수은 반도체'
li4 = '조달 자금 조달 자금 하이닉스 대출 농협 대출 농협 수은 농협 조달 수은 하이닉스 자금'
li5 = '금융 성수 성수 금융 위원장 금융 위원장 설명 설명 성수 시설'

words = dict(Counter(li1.split(' ')+li2.split(' ')+li3.split(' ')+li4.split(' ')+li5.split(' ')))
mask_array=np.array(Image.open('./circle.png'))

wordcloud = WordCloud(
    font_path = 'malgun.ttf',
    background_color='white',
    colormap='Blues',
    mask=mask_array,
).generate_from_frequencies(words)

plt.figure(figsize=(5,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 400.5, 389.5, -0.5)
